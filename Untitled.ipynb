# %% [markdown]
# # 제목
# 1. 항목1
# 1. 항목2
# 1. 항목3

# %%
print('hello')
# Out:
# hello

# %%
a = print ( 2** 1024)
a
# Out:
# 

# %%
import pandas_datareader as pdr

# %%
# FRED
df = pdr.DataReader('DEXKOUS', 'fred', '2010-01-01')
df.head(5)
# Out:
#             DEXKOUS
# DATE
# 2010-01-01      NaN
# 2010-01-04   1149.0
# 2010-01-05   1138.2
# 2010-01-06   1130.0
# 2010-01-07   1135.0

# %%
df.tail()
# Out:
#             DEXKOUS
# DATE
# 2018-02-19      NaN
# 2018-02-20  1072.85
# 2018-02-21  1076.11
# 2018-02-22  1077.61
# 2018-02-23  1075.77

# %%
# %matplotlib inline

df.plot(figsize=(14,8))

# %%
ls
# Out:
# FinanceData 12기 강의자료 목록.ipynb  README.md  Untitled.ipynb

# %%
ls
# Out:
# FinanceData 12기 강의자료 목록.ipynb  README.md  Untitled.ipynb

# %%
ll
# Out:
# total 96
# -rw-rw-r-- 1 ec2-user  9246 Mar  4 05:08 FinanceData 12기 강의자료 목록.ipynb
# -rw-r--r-- 1 ec2-user   570 Feb 25 07:44 README.md
# -rw-rw-r-- 1 ec2-user 80777 Mar  4 05:22 Untitled.ipynb

# %%
import numbers as np

# %%
np?
